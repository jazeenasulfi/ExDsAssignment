# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("EastWestAirlines.csv")
df_orig = df.copy()
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %% [markdown]
# # **EDA**

# %%
df.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
df_eda = df.rename(columns = {"ID#":"ID","Award?":"Award"})
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df_eda.columns
# Out:
# Index(['ID', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
#using minmax scaler function
#transformation of single column needs "values.reshape(-1,1)"
from sklearn.preprocessing import MinMaxScaler

ms = MinMaxScaler()

df_eda.iloc[:,:]=ms.fit_transform(df_eda.iloc[:,:])
# Out:
# <ipython-input-267-09120601c3c7>:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_eda.iloc[:,:]=ms.fit_transform(df_eda.iloc[:,:])

# %%
df_eda_norm  = df_eda.drop(['ID'],axis=1)

# %% [markdown]
# # **Heirarchical cluster**

# %%
df = df_eda_norm

# %%
# create dendrogram
import scipy.cluster.hierarchy as sch
sch.dendrogram(sch.linkage(df, method='complete'))
plt.show()

# %%
# create clusters
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage = 'complete')
hc.fit(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# AgglomerativeClustering(affinity='euclidean', linkage='complete', n_clusters=5)

# %%
yhc = hc.fit_predict(df)
yhc
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([0, 0, 0, ..., 2, 0, 0])

# %%
df_eda["h_cluster"] = yhc
df_eda
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
# Plotting barplot using groupby method to get visualization of how many row no. in each cluster

fig, ax = plt.subplots(figsize=(10, 6))
df_eda.groupby(['h_cluster']).count()['ID'].plot(kind='bar')
plt.ylabel('ID Counts')
plt.title('Hierarchical Clustering',fontsize='large',fontweight='bold')
ax.set_xlabel('Clusters', fontsize='large', fontweight='bold')
ax.set_ylabel('ID counts', fontsize='large', fontweight='bold')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()

# %% [markdown]
# # **K MEANS**

# %%
df = df_eda_norm
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
#find the optimum number of clusters

from sklearn.cluster import KMeans

# %%
#inertia calculates the within cluster sum of squares

wcss = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [1830.793212858411,
#  823.6756984125209,
#  625.1684881570724,
#  436.70885761932567,
#  348.9433217254141,
#  315.31559648428936,
#  287.73076207313125,
#  263.214299891393,
#  243.92721754767044,
#  231.7988392842746]

# %%
sns.lineplot(x=range(1,11),y=wcss)
# Out:
# <Axes: >

# %%
# Consider cluster = 4
kmeans = KMeans(n_clusters=4)
predict=kmeans.fit_predict(df.iloc[:,1:])
predict
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 2, 0, 0], dtype=int32)

# %%
df_eda["k_cluster"] =kmeans.labels_
df_eda
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
kmeans.cluster_centers_
# Out:
# array([[ 8.28362120e-03,  2.31945177e-02,  8.96151819e-03,
#          1.05429626e-03,  1.26482465e-02,  7.54496083e-02,
#          7.35308092e-03,  1.24327389e-02,  4.36111859e-01,
#          7.21644966e-16],
#        [ 2.60542873e-02,  3.90044577e-02,  1.63447251e-02,
#          2.22882615e-03,  3.35642727e-02,  1.21825219e-01,
#          3.34267751e-02,  5.94073285e-02,  5.22892182e-01,
#          1.00000000e+00],
#        [ 1.77912301e-02,  7.28960396e-01,  6.18811881e-04,
#          6.49752475e-03,  1.72970238e-01,  2.34903868e-01,
#          2.31602349e-02,  4.04212591e-02,  5.86139300e-01,
#          1.00000000e+00],
#        [ 6.55837114e-03,  6.44122383e-01,  8.05152979e-04,
#          5.63607085e-03,  1.18636504e-01,  2.00595439e-01,
#          7.31260853e-03,  1.19405706e-02,  5.34640411e-01,
#         -2.77555756e-16]])

# %%
df1 = df_eda.groupby("k_cluster").mean().reset_index()
df1
# Out:
#    k_cluster        ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0          0  0.568004  0.023901    0.008284   0.023195   0.008962   0.001054
# 1          1  0.473573  0.048995    0.026054   0.039004   0.016345   0.002229
# 2          2  0.400999  0.063535    0.017791   0.728960   0.000619   0.006498
# 3          3  0.455836  0.069234    0.006558   0.644122   0.000805   0.005636
#
#    Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0     0.012648     0.075450           0.007353         0.012433
# 1     0.033564     0.121825           0.033427         0.059407
# 2     0.172970     0.234904           0.023160         0.040421
# 3     0.118637     0.200595           0.007313         0.011941
#
#    Days_since_enroll  Award  h_cluster
# 0           0.436112    0.0   0.052715
# 1           0.522892    1.0   2.014859
# 2           0.586139    1.0   1.600248
# 3           0.534640    0.0   0.000000

# %% [markdown]
# # **DBSCAN**

# %%
df = df_eda_norm
from sklearn.cluster import DBSCAN
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
from sklearn.neighbors import NearestNeighbors

nn = NearestNeighbors(n_neighbors=8)#suppose nieghbour = 8

nbrs = nn.fit(df)

distances,indices = nbrs.kneighbors(df)

# %%
distances = np.sort(distances,axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
dbscan = DBSCAN(eps=0.2, min_samples=5)
dbscan.fit_predict(df)
# Out:
# array([0, 0, 0, ..., 4, 0, 0])

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 4, 0, 0])

# %%
df_eda['DB_cluster']=dbscan.labels_
df.head()
# Out:
#     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0  0.016508         0.0       0.00        0.0        0.0     0.000660
# 1  0.011288         0.0       0.00        0.0        0.0     0.000815
# 2  0.024257         0.0       0.00        0.0        0.0     0.015636
# 3  0.008667         0.0       0.00        0.0        0.0     0.001896
# 4  0.057338         0.0       0.75        0.0        0.0     0.164211
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0     0.011628           0.000000         0.000000           0.843742    0.0
# 1     0.023256           0.000000         0.000000           0.839884    0.0
# 2     0.046512           0.000000         0.000000           0.847842    0.0
# 3     0.011628           0.000000         0.000000           0.837955    0.0
# 4     0.302326           0.067398         0.075472           0.835905    1.0

# %%
# Use pandas filtering and get noisy datapoints -1
df_eda[df_eda['DB_cluster']==-1]
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 8     0.001990  0.259850    0.000000       0.50        0.5        0.0
# 65    0.016169  0.031624    0.000000       0.50        0.0        0.0
# 70    0.017662  0.049511    0.451292       0.25        0.0        0.0
# 87    0.022139  0.357498    0.000000       0.50        0.0        0.0
# 94    0.023881  0.108837    0.000000       1.00        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3851  0.963433  0.007008    0.000000       0.00        0.5        0.0
# 3883  0.971393  0.074005    0.000000       1.00        0.0        0.0
# 3897  0.974876  0.105483    0.264980       0.50        0.0        0.0
# 3911  0.978358  0.032802    0.203893       0.00        0.0        0.0
# 3917  0.979851  0.076692    0.000000       0.75        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...

# %%
from sklearn.metrics import silhouette_score
silhouette_score(df_eda,df_eda['DB_cluster'])
# Out:
# 0.76273264560191

# %%
#All clusters in one dataframe
df_eda
# Out:
#             ID   Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     0.000000  0.016508         0.0       0.00        0.0        0.0
# 1     0.000249  0.011288         0.0       0.00        0.0        0.0
# 2     0.000498  0.024257         0.0       0.00        0.0        0.0
# 3     0.000746  0.008667         0.0       0.00        0.0        0.0
# 4     0.000995  0.057338         0.0       0.75        0.0        0.0
# ...        ...       ...         ...        ...        ...        ...
# 3994  0.999005  0.010837         0.0       0.00        0.0        0.0
# 3995  0.999254  0.037766         0.0       0.00        0.0        0.0
# 3996  0.999502  0.043169         0.0       0.50        0.0        0.0
# 3997  0.999751  0.032202         0.0       0.00        0.0        0.0
# 3998  1.000000  0.001769         0.0       0.00        0.0        0.0
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# ...
